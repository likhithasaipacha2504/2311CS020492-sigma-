# %% [markdown]
# # 24-01-25

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import warnings
iris_data=sns.load_dataset("iris")
df=sns.load_dataset('taxis')

# %%
sns.scatterplot(x=iris_data['sepal_length'],y=iris_data['petal_length'])
plt.show()

# %%
sns.scatterplot(x=iris_data['sepal_length'],y=iris_data['petal_length'],hue=iris_data['species'],palette=['r','g','b'])
plt.show()

# %% [markdown]
# #25-01-2025

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=sns.load_dataset('taxis')
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
df=sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df['who'].unique()
# Out:
# array(['man', 'woman', 'child'], dtype=object)

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886     True
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 107

# %%
df[df.duplicated]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 47          1       3  female   NaN      0      0   7.7500        Q   Third
# 76          0       3    male   NaN      0      0   7.8958        S   Third
# 77          0       3    male   NaN      0      0   8.0500        S   Third
# 87          0       3    male   NaN      0      0   8.0500        S   Third
# 95          0       3    male   NaN      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 870         0       3    male  26.0      0      0   7.8958        S   Third
# 877         0       3    male  19.0      0      0   7.8958        S   Third
# 878         0       3    male   NaN      0      0   7.8958        S   Third
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0           0       3    male  22.0      1      0   7.2500        S  Third
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 2           1       3  female  26.0      0      0   7.9250        S  Third
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 4           0       3    male  35.0      0      0   8.0500        S  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 885         0       3  female  39.0      0      5  29.1250        Q  Third
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 888         0       3  female   NaN      1      2  23.4500        S  Third
# 889         1       1    male  26.0      0      0  30.0000        C  First
# 890         0       3    male  32.0      0      0   7.7500        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.reset_index()
# Out:
#      index  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0        0         0       3    male  22.0      1      0   7.2500        S
# 1        1         1       1  female  38.0      1      0  71.2833        C
# 2        2         1       3  female  26.0      0      0   7.9250        S
# 3        3         1       1  female  35.0      1      0  53.1000        S
# 4        4         0       3    male  35.0      0      0   8.0500        S
# ..     ...       ...     ...     ...   ...    ...    ...      ...      ...
# 779    885         0       3  female  39.0      0      5  29.1250        Q
# 780    887         1       1  female  19.0      0      0  30.0000        S
# 781    888         0       3  female   NaN      1      2  23.4500        S
# 782    889         1       1    male  26.0      0      0  30.0000        C
# 783    890         0       3    male  32.0      0      0   7.7500        Q
#
#      class    who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# #the index is started from 0 to 784

# %%
df.reset_index(drop=True)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0           0       3    male  22.0      1      0   7.2500        S  Third
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 2           1       3  female  26.0      0      0   7.9250        S  Third
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 4           0       3    male  35.0      0      0   8.0500        S  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 779         0       3  female  39.0      0      5  29.1250        Q  Third
# 780         1       1  female  19.0      0      0  30.0000        S  First
# 781         0       3  female   NaN      1      2  23.4500        S  Third
# 782         1       1    male  26.0      0      0  30.0000        C  First
# 783         0       3    male  32.0      0      0   7.7500        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0           0       3    male  22.0      1      0   7.2500        S  Third
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 2           1       3  female  26.0      0      0   7.9250        S  Third
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 4           0       3    male  35.0      0      0   8.0500        S  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 885         0       3  female  39.0      0      5  29.1250        Q  Third
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 888         0       3  female   NaN      1      2  23.4500        S  Third
# 889         1       1    male  26.0      0      0  30.0000        C  First
# 890         0       3    male  32.0      0      0   7.7500        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# #inplace is for perminent changes

# %%
df.reset_index(drop=True,inplace=True)
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0           0       3    male  22.0      1      0   7.2500        S  Third
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 2           1       3  female  26.0      0      0   7.9250        S  Third
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 4           0       3    male  35.0      0      0   8.0500        S  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 779         0       3  female  39.0      0      5  29.1250        Q  Third
# 780         1       1  female  19.0      0      0  30.0000        S  First
# 781         0       3  female   NaN      1      2  23.4500        S  Third
# 782         1       1    male  26.0      0      0  30.0000        C  First
# 783         0       3    male  32.0      0      0   7.7500        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.shape
# Out:
# (784, 15)

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            106
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           582
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df['deck'].isnull().sum()
# Out:
# 582

# %%
df['age'].isnull().sum()
# Out:
# 106

# %%
sns.heatmap(df.isnull())
plt.show()

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 768         1       1  female  47.0      1      1  52.5542        S  First
# 769         0       1    male  33.0      0      0   5.0000        S  First
# 774         1       1  female  56.0      0      1  83.1583        C  First
# 780         1       1  female  19.0      0      0  30.0000        S  First
# 782         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# #If we are deleting the data more than 10%  should use delete

# %%
(df.isnull().sum()/df.shape[0])*100
# Out:
# survived       0.0
# pclass         0.0
# sex            0.0
# age            0.0
# sibsp          0.0
# parch          0.0
# fare           0.0
# embarked       0.0
# class          0.0
# who            0.0
# adult_male     0.0
# deck           0.0
# embark_town    0.0
# alive          0.0
# alone          0.0
# dtype: float64

# %%
df.drop('fare',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-49c444cef557> in <cell line: 0>()
# ----> 1 df.drop('fare',axis=1,inplace=True)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'embarked',
#        'class', 'who', 'adult_male', 'deck', 'embark_town', 'alive', 'alone'],
#       dtype='object')

# %%
df['age'] = pd.to_numeric(df['age'], errors='coerce')
df['age'].fillna(df['age'].median(), inplace=True)
df['embark_town'].fillna(df['embark_town'].mode()[0], inplace=True)

# %%
df["embark_town"].fillna(df['embark_town'].mode()[0],inplace=True)

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch embarked  class    who  \
# 1           1       1  female  38.0      1      0        C  First  woman
# 3           1       1  female  35.0      1      0        S  First  woman
# 6           0       1    male  54.0      0      0        S  First    man
# 10          1       3  female   4.0      1      1        S  Third  child
# 11          1       1  female  58.0      0      0        S  First  woman
# ..        ...     ...     ...   ...    ...    ...      ...    ...    ...
# 768         1       1  female  47.0      1      1        S  First  woman
# 769         0       1    male  33.0      0      0        S  First    man
# 774         1       1  female  56.0      0      1        C  First  woman
# 780         1       1  female  19.0      0      0        S  First  woman
# 782         1       1    male  26.0      0      0        C  First    man
#
#      adult_male deck  embark_town alive  alone
# ...

# %%
df['embarked'].mode()
# Out:
# 0    S
# Name: embarked, dtype: object

# %%
df['embarked'].fillna(df['embarked'].mode()[0],inplace=True)
df
# Out:
#      survived  pclass     sex   age  sibsp  parch embarked  class    who  \
# 1           1       1  female  38.0      1      0        C  First  woman
# 3           1       1  female  35.0      1      0        S  First  woman
# 6           0       1    male  54.0      0      0        S  First    man
# 10          1       3  female   4.0      1      1        S  Third  child
# 11          1       1  female  58.0      0      0        S  First  woman
# ..        ...     ...     ...   ...    ...    ...      ...    ...    ...
# 768         1       1  female  47.0      1      1        S  First  woman
# 769         0       1    male  33.0      0      0        S  First    man
# 774         1       1  female  56.0      0      1        C  First  woman
# 780         1       1  female  19.0      0      0        S  First  woman
# 782         1       1    male  26.0      0      0        C  First    man
#
#      adult_male deck  embark_town alive  alone
# ...

# %%
print('Missing values before imputation - ',df['embarked'].isnull().sum())
df['embarked'].fillna(df['embarked'].mode()[0],inplace=True)
print('Missing values after imputation - ',df['embarked'].isnull().sum())
# Out:
# Missing values before imputation -  0
# Missing values after imputation -  0

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch embarked  class    who  \
# 1           1       1  female  38.0      1      0        C  First  woman
# 3           1       1  female  35.0      1      0        S  First  woman
# 6           0       1    male  54.0      0      0        S  First    man
# 10          1       3  female   4.0      1      1        S  Third  child
# 11          1       1  female  58.0      0      0        S  First  woman
# ..        ...     ...     ...   ...    ...    ...      ...    ...    ...
# 768         1       1  female  47.0      1      1        S  First  woman
# 769         0       1    male  33.0      0      0        S  First    man
# 774         1       1  female  56.0      0      1        C  First  woman
# 780         1       1  female  19.0      0      0        S  First  woman
# 782         1       1    male  26.0      0      0        C  First    man
#
#      adult_male deck  embark_town alive  alone
# ...

# %%
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()
df['embarked']=lb.fit_transform(df['embarked'])

# %%
df['embarked'].unique()
# Out:
# array([0, 2, 1])

# %%
df['class'].unique()
# Out:
# ['First', 'Third', 'Second']
# Categories (3, object): ['First', 'Second', 'Third']

# %%
print('Before ' ,df['embark_town'].unique())
# Change this line to assign to the column directly, not a DataFrame subset
df['embark_town'] = lb.fit_transform(df['embark_town'])
print('After ' ,df['embark_town'].unique())
# Out:
# Before  ['Cherbourg' 'Southampton' 'Queenstown']
# After  [0 2 1]

# %%
  print('')
