# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=sns.get_dataset_names()
df
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df= sns.load_dataset('taxis')
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6433 entries, 0 to 6432
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pickup           6433 non-null   datetime64[ns]
#  1   dropoff          6433 non-null   datetime64[ns]
#  2   passengers       6433 non-null   int64
#  3   distance         6433 non-null   float64
#  4   fare             6433 non-null   float64
#  5   tip              6433 non-null   float64
#  6   tolls            6433 non-null   float64
#  7   total            6433 non-null   float64
#  8   color            6433 non-null   object
#  9   payment          6389 non-null   object
#  10  pickup_zone      6407 non-null   object
#  11  dropoff_zone     6388 non-null   object
#  12  pickup_borough   6407 non-null   object
#  13  dropoff_borough  6388 non-null   object
# dtypes: datetime64[ns](2), float64(5), int64(1), object(6)
# memory usage: 703.7+ KB

# %%
df.sample(10)
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 1357 2019-03-21 09:29:18 2019-03-21 09:41:09           1      0.74   8.5
# 2755 2019-03-12 12:05:14 2019-03-12 12:51:15           0     10.10  39.0
# 3236 2019-03-21 10:45:34 2019-03-21 10:54:20           1      1.18   7.5
# 2086 2019-03-15 17:22:21 2019-03-15 17:37:47           1      1.27  10.5
# 6161 2019-03-13 08:11:54 2019-03-13 08:24:56           1      1.15   9.5
# 2447 2019-03-06 11:32:32 2019-03-06 11:47:56           1      2.08  11.5
# 4411 2019-03-26 10:53:51 2019-03-26 11:25:27           1      6.39  25.5
# 6273 2019-03-06 00:07:09 2019-03-06 00:16:18           1      2.58   9.5
# 3852 2019-03-26 16:21:11 2019-03-26 17:26:21           3     18.06  52.0
# 1877 2019-03-01 17:23:57 2019-03-01 17:27:00           1      0.40   4.0
#
#         tip  tolls  total   color      payment               pickup_zone  \
# 1357   0.00   0.00  11.80  yellow         cash               Murray Hill
# ...

# %%
df.tail(10)
# Out:
#                   pickup             dropoff  passengers  distance   fare  \
# 6423 2019-03-12 08:10:47 2019-03-12 08:35:35           1      4.30  18.50
# 6424 2019-03-30 20:52:15 2019-03-30 20:59:55           1      1.70   8.00
# 6425 2019-03-07 15:34:30 2019-03-07 16:31:06           1      9.12  26.32
# 6426 2019-03-28 08:04:47 2019-03-28 08:07:46           1      0.71   4.50
# 6427 2019-03-23 18:26:09 2019-03-23 18:49:12           1      7.07  20.00
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.50
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.00
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.00
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.00
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.00
#
#        tip  tolls  total  color      payment          pickup_zone  \
# 6423  0.00    0.0  19.30  green  credit card         Saint Albans
# ...

# %%
df.head(10)
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
# 5 2019-03-11 10:37:23 2019-03-11 10:47:31           1      0.49   7.5  2.16
# 6 2019-03-26 21:07:31 2019-03-26 21:17:29           1      3.65  13.0  2.00
# 7 2019-03-22 12:47:13 2019-03-22 12:58:17           0      1.40   8.5  0.00
# 8 2019-03-23 11:48:50 2019-03-23 12:06:14           1      3.63  15.0  1.00
# 9 2019-03-08 16:18:37 2019-03-08 16:26:57           1      1.52   8.0  1.00
#
#    tolls  total   color      payment                pickup_zone  \
# 0    0.0  12.95  yellow  credit card            Lenox Hill West
# ...

# %%
df['color'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6428    False
# 6429    False
# 6430    False
# 6431    False
# 6432    False
# Name: color, Length: 6433, dtype: bool

# %%
df['color']
# Out:
# 0       yellow
# 1       yellow
# 2       yellow
# 3       yellow
# 4       yellow
#          ...
# 6428     green
# 6429     green
# 6430     green
# 6431     green
# 6432     green
# Name: color, Length: 6433, dtype: object

# %%
df['payment']
# Out:
# 0       credit card
# 1              cash
# 2       credit card
# 3       credit card
# 4       credit card
#            ...
# 6428    credit card
# 6429    credit card
# 6430           cash
# 6431    credit card
# 6432    credit card
# Name: payment, Length: 6433, dtype: object

# %%
df['payment'].isnull().sum()
# Out:
# 44

# %%
#returns the sum of null value
df.isnull().sum()
# Out:
# pickup              0
# dropoff             0
# passengers          0
# distance            0
# fare                0
# tip                 0
# tolls               0
# total               0
# color               0
# payment            44
# pickup_zone        26
# dropoff_zone       45
# pickup_borough     26
# dropoff_borough    45
# dtype: int64

# %%
df.shape
# Out:
# (6433, 14)

# %%
(45/6433)*100
# Out:
# 0.699518109746619

# %%
#This is formatted as code
##To find the percentage of missing values
df.isnull().sum()/df.shape[0]*100
# Out:
# pickup             0.000000
# dropoff            0.000000
# passengers         0.000000
# distance           0.000000
# fare               0.000000
# tip                0.000000
# tolls              0.000000
# total              0.000000
# color              0.000000
# payment            0.683973
# pickup_zone        0.404166
# dropoff_zone       0.699518
# pickup_borough     0.404166
# dropoff_borough    0.699518
# dtype: float64

# %%
## find the missing values greather than 20%

#like financial
df.drop('pickup_zone',axis=1)
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment  \
# ...

# %%
df.drop('dropoff',axis=1, inplace=True)
df
# Out:
#                   pickup  passengers  distance  fare   tip  tolls  total  \
# 0    2019-03-23 20:21:09           1      1.60   7.0  2.15    0.0  12.95
# 1    2019-03-04 16:11:55           1      0.79   5.0  0.00    0.0   9.30
# 2    2019-03-27 17:53:01           1      1.37   7.5  2.36    0.0  14.16
# 3    2019-03-10 01:23:59           1      7.70  27.0  6.15    0.0  36.95
# 4    2019-03-30 13:27:42           3      2.16   9.0  1.10    0.0  13.40
# ...                  ...         ...       ...   ...   ...    ...    ...
# 6428 2019-03-31 09:51:53           1      0.75   4.5  1.06    0.0   6.36
# 6429 2019-03-31 17:38:00           1     18.74  58.0  0.00    0.0  58.80
# 6430 2019-03-23 22:55:18           1      4.14  16.0  0.00    0.0  17.30
# 6431 2019-03-04 10:09:25           1      1.12   6.0  0.00    0.0   6.80
# 6432 2019-03-13 19:31:22           1      3.85  15.0  3.36    0.0  20.16
#
#        color      payment            pickup_zone  \
# ...

# %%
df.drop(['pickup','color','payment','total'],axis=1)
# Out:
#       passengers  distance  fare   tip  tolls            pickup_zone  \
# 0              1      1.60   7.0  2.15    0.0        Lenox Hill West
# 1              1      0.79   5.0  0.00    0.0  Upper West Side South
# 2              1      1.37   7.5  2.36    0.0          Alphabet City
# 3              1      7.70  27.0  6.15    0.0              Hudson Sq
# 4              3      2.16   9.0  1.10    0.0           Midtown East
# ...          ...       ...   ...   ...    ...                    ...
# 6428           1      0.75   4.5  1.06    0.0      East Harlem North
# 6429           1     18.74  58.0  0.00    0.0                Jamaica
# 6430           1      4.14  16.0  0.00    0.0    Crown Heights North
# 6431           1      1.12   6.0  0.00    0.0          East New York
# 6432           1      3.85  15.0  3.36    0.0            Boerum Hill
#
#                           dropoff_zone pickup_borough dropoff_borough
# ...

# %%
#TO MAKE THE CHANGES PERMENENT WE NEED TO USE INPLACE IS TRUE
df.drop(['pickup','color','payment','total'],axis=1,inplace=True)

# %%
df
# Out:
#       passengers  distance  fare   tip  tolls            pickup_zone  \
# 0              1      1.60   7.0  2.15    0.0        Lenox Hill West
# 1              1      0.79   5.0  0.00    0.0  Upper West Side South
# 2              1      1.37   7.5  2.36    0.0          Alphabet City
# 3              1      7.70  27.0  6.15    0.0              Hudson Sq
# 4              3      2.16   9.0  1.10    0.0           Midtown East
# ...          ...       ...   ...   ...    ...                    ...
# 6428           1      0.75   4.5  1.06    0.0      East Harlem North
# 6429           1     18.74  58.0  0.00    0.0                Jamaica
# 6430           1      4.14  16.0  0.00    0.0    Crown Heights North
# 6431           1      1.12   6.0  0.00    0.0          East New York
# 6432           1      3.85  15.0  3.36    0.0            Boerum Hill
#
#                           dropoff_zone pickup_borough dropoff_borough
# ...

# %%
df.drop([2,3,6430])
# Out:
#       passengers  distance  fare   tip  tolls                pickup_zone  \
# 0              1      1.60   7.0  2.15    0.0            Lenox Hill West
# 1              1      0.79   5.0  0.00    0.0      Upper West Side South
# 4              3      2.16   9.0  1.10    0.0               Midtown East
# 5              1      0.49   7.5  2.16    0.0  Times Sq/Theatre District
# 6              1      3.65  13.0  2.00    0.0          Battery Park City
# ...          ...       ...   ...   ...    ...                        ...
# 6427           1      7.07  20.0  0.00    0.0                Parkchester
# 6428           1      0.75   4.5  1.06    0.0          East Harlem North
# 6429           1     18.74  58.0  0.00    0.0                    Jamaica
# 6431           1      1.12   6.0  0.00    0.0              East New York
# 6432           1      3.85  15.0  3.36    0.0                Boerum Hill
#
#                           dropoff_zone pickup_borough dropoff_borough
# ...

# %%
df.drop.([2,3,6430,6432]xis=0,index=True)
# Out:
#   Cell In[27], line 1
#     df.drop.([2,3,6430,6432]xis=0,index=True)
#             ^
# SyntaxError: invalid syntax
